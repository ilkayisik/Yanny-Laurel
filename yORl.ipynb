# %%
'''This notebook uses functions from Allen Downeys ThinkDSP (2015) '''

# %%
# First do the necessary imports
from __future__ import print_function, division
# %matplotlib inline

import thinkdsp
import thinkplot
import numpy as np
from IPython.display import Audio

# %%
# now load the infamous recording
wave = thinkdsp.read_wave('yORl.wav')

# %%
# listen to it
wave.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# pick the part where it obviously says 'Yanny'
start = 1.1
duration = 0.9
segment = wave.segment(start, duration)
segment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# plot this segment
segment.plot()
thinkplot.config(xlabel='Time (s)')

# %%
# create the freq spectrum
spectrum = segment.make_spectrum()
spectrum.plot()
thinkplot.config(xlabel='Frequency (Hz)')

# %%
# create a low pass filtered version
#spectrum.low_pass(1000)

# if you are a Laurel person you can try applying a high pass filter
#spectrum.high_pass(1000)

# band pass filter
spectrum.band_stop(low_cutoff=200, high_cutoff=800 )

# plot it
spectrum.plot(high=1000)
thinkplot.config(xlabel='Frequency (Hz)')

# %%
filtered = spectrum.make_wave()
filtered.plot()
thinkplot.config(xlabel='Time (s)')

# %%
segment.plot()
thinkplot.config(xlabel='Time (s)')

# %%
segment.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
filtered.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# now I hear Laurel, how about you?
